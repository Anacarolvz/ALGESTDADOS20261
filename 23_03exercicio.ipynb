# %% [markdown]
# <a href="https://colab.research.google.com/github/Anacarolvz/ALGESTDADOS20261/blob/main/23_03exercicio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#3 solicite um numero inteiro. verifique se ele é par (divisível por 2) e exiba uma mensagem infon

num = int(input('digite numero: ")
if num%2 == 0:
                print("nbumero par!")
else:
                print'

# %%
#9 peça um um  numero ao usuario. sem usar == 0, use o proprio

# %%
#11 Leia o nome do usuário. Se o nome for uma string vazia (falsy), exiba "Nenhum nome digitado.", caso contrário, exiba "Olá, [nome]!" usando f-string.
nome = input("digite seu nome:")
if bool(nome) is false:
     print("nenhum nome digitado. ")
else:
    print(f"óla,{nome}!")
