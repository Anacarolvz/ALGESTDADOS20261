# %% [markdown]
# <a href="https://colab.research.google.com/github/Anacarolvz/ALGESTDADOS20261/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Leia a nota de um aluno. Classifique usando elif: nota ≥ 9 → "A — Excelente", ≥ 7 → "B — Aprovado", ≥ 5 → "C — Recuperação", abaixo → "D — Reprovado".

nota = float(input("digite a sua nota: "))
if 10 >= nota >= 9: print("A - excelente")
elif nota >= 7: print("B - aprovado")
elif nota >=5: print("C - recuperação")
elif nota >=0: print("D - reprovação")
else: print("nota inválida")
# Out:
# digite a sua nota: 8
# B - aprovado

# %%
#02 - Dias da semana
#Leia um número de 1 a 7 e exiba o nome do dia correspondente
#(1 = Segunda, ..., 7 = Domingo).
#Para qualquer outro número, exiba "Número inválido".

# %%
#03 - Nota Válida
#Leia uma nota.
#Valide se está entre 0 e 10 usando encadeamento de comparações (0 <= nota <= 10).
#Se inválida, exiba "Nota inválida!".
#Se válida, exiba "Nota registrada: [nota]".

# %%
#04 - Faixa Etária
#Leia a idade.
#Classifique: menor de 12 → "Criança", 12 a 17 → "Adolescente", 18 a 59 → "Adulto", 60 ou mais → "Idoso".
#Valide que a idade não é negativa

# %%
#05 - Cardápio com Validação
#Exiba um menu com 3 opções (ex: 1-Água R$2, 2-Suco R$6, 3-Café R$4).
#Leia a escolha.
#Valide com not (1 <= item <= 3).
#Se inválido, exiba erro; se válido, exiba o item e o preço.

# %%
#06 - Classificação de Temperatura
#Leia a temperatura.
#Classifique usando elif: abaixo de 0 → "Congelante", 0 a 15 → "Frio", 16 a 25 → "Agradável", 26 a 35 → "Quente", acima de 35 → "Muito quente".

# %%
#07 - Calculadora Simples Validada
#Leia dois números e um operador (+, -, *, /). Use elif para realizar a operação correta.
#Valide a divisão por zero. Para operador inválido, exiba "Operador desconhecido".
numA = float(input('numero 1:'))
operedor = input('operedor:')
numB = float(input('numero 2:'))
if operador =='+':
  resultado=numA+numB
  print(resultado|)
elif operador == '-':
  #código para subtração
elif operador == '*':
  #código para multiplicação
elif operador == '/':
 if numB != 0:
  #código par divisão
else:
      print("operação invalida")
else:
  print("operador desconhecido")
# Out:
#   File "/tmp/ipykernel_5539/173380833.py", line 11
#     elif operador == '*':
#     ^
# IndentationError: expected an indented block after 'elif' statement on line 9
